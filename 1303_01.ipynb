# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("auto-mpg.csv")

# %%
df['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df['horsepower'] = df['horsepower'].replace("?", df[df['horsepower']!="?"]['horsepower'].astype("int64").mean())

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df = df[df['horsepower']!="?"]

# %%
df['horsepower'] = df['horsepower'].astype('int')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          86    2790          15.6
# 394  44.0          4          97.0          52    2130          24.6
# 395  32.0          4         135.0          84    2295          11.6
# 396  28.0          4         120.0          79    2625          18.6
# 397  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.describe(include='object')
# Out:
#        horsepower    car name
# count         398         398
# unique         94         305
# top           150  ford pinto
# freq           22           6

# %%
df.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.771543 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.839061  0.896017
# displacement -0.804203   0.950721      1.000000    0.893760  0.932824
# horsepower   -0.771543   0.839061      0.893760    1.000000  0.860676
# weight       -0.831741   0.896017      0.932824    0.860676  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.684376 -0.417457
# model year    0.579267  -0.348746     -0.370164   -0.411750 -0.306564
# origin        0.563450  -0.562543     -0.609409   -0.453613 -0.581024
#
#               acceleration  model year    origin
# mpg               0.420289    0.579267  0.563450
# cylinders        -0.505419   -0.348746 -0.562543
# displacement     -0.543684   -0.370164 -0.609409
# horsepower       -0.684376   -0.411750 -0.453613
# weight           -0.417457   -0.306564 -0.581024
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True,vmin=0)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True,vmax=0.5)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True,linewidths=0.2)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor='red')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True,linewidths=0.5,cbar=False)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True,linewidths=0.5,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df,x='horsepower',y='weight')
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='weight'>

# %%
sns.scatterplot(data=df,x='horsepower',y='weight',hue='cylinders')
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='weight'>

# %%
sns.scatterplot(data=df,x='horsepower',y='weight',style='cylinders',hue='cylinders')
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='weight'>

# %%
sns.scatterplot(data=df,x='horsepower',y='weight',style='cylinders',hue='cylinders',s=100)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='weight'>

# %%
import plotly.express as px

# %%
pip install --upgrade plotly
# Out:
# Requirement already up-to-date: plotly in c:\programdata\anaconda3\lib\site-packages (6.6.0)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv("social_media_engagement.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   post_id          100 non-null    int64
#  1   platform         100 non-null    object
#  2   post_type        100 non-null    object
#  3   post_time        100 non-null    object
#  4   likes            100 non-null    int64
#  5   comments         100 non-null    int64
#  6   shares           100 non-null    int64
#  7   post_day         100 non-null    object
#  8   sentiment_score  100 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 7.2+ KB

# %%
df.head()
# Out:
#    post_id   platform post_type        post_time  likes  comments  shares  \
# 0        1   Facebook     image  8/17/2023 14:45   2121       474     628
# 1        2   Facebook  carousel   5/14/2023 0:45   3660       432     694
# 2        3  Instagram      poll  2/21/2023 16:15   4955       408     688
# 3        4    Twitter     image  11/16/2023 0:45   1183        90     187
# 4        5    Twitter     video   5/23/2023 0:30   3499       247     286
#
#    post_day sentiment_score
# 0  Thursday        positive
# 1    Sunday         neutral
# 2   Tuesday        negative
# 3  Thursday        negative
# 4   Tuesday        positive

# %%
df.tail()
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 95       96  Instagram  carousel   7/12/2023 17:45     36       294     911
# 96       97    Twitter     video  10/27/2023 23:45    314       108     458
# 97       98    Twitter      text     8/5/2023 8:45    229       179      38
# 98       99  Instagram      poll  12/29/2023 12:15   5000       500     204
# 99      100  Instagram     image    6/6/2023 21:00   4483       357      25
#
#      post_day sentiment_score
# 95  Wednesday        positive
# 96     Friday         neutral
# 97   Saturday        positive
# 98     Friday        positive
# 99    Tuesday         neutral

# %%
df.isna().sum()
# Out:
# post_id            0
# platform           0
# post_type          0
# post_time          0
# likes              0
# comments           0
# shares             0
# post_day           0
# sentiment_score    0
# dtype: int64

# %%
df.nunique()
# Out:
# post_id            100
# platform             3
# post_type            5
# post_time           99
# likes               93
# comments            85
# shares              96
# post_day             7
# sentiment_score      3
# dtype: int64

# %%
df.dtypes
# Out:
# post_id             int64
# platform           object
# post_type          object
# post_time          object
# likes               int64
# comments            int64
# shares              int64
# post_day           object
# sentiment_score    object
# dtype: object

# %%
df.platform.unique()
# Out:
# array(['Facebook', 'Instagram', 'Twitter'], dtype=object)

# %%
df.post_type.unique()
# Out:
# array(['image', 'carousel', 'poll', 'video', 'text'], dtype=object)

# %%
df.sentiment_score.unique()
# Out:
# array(['positive', 'neutral', 'negative'], dtype=object)

# %%
df[df['platform']=='Facebook']['likes']
# Out:
# 0     2121
# 1     3660
# 8      317
# 12      45
# 14     889
# 19     455
# 25    1992
# 27    2083
# 28     548
# 29    4594
# 30    4795
# 35    5000
# 36    4245
# 38    5000
# 46    4726
# 47    5000
# 57    2204
# 61    3742
# 65    2265
# 66    2026
# 69    3094
# 71    1690
# 72    3026
# 74    5000
# 79     553
# 80    2642
# 83    1203
# 84    2566
# 87    3404
# 90    3956
# 91    1857
# 93    1694
# Name: likes, dtype: int64

# %%
df.groupby("platform")['likes'].sum()
# Out:
# platform
# Facebook      86392
# Instagram    107994
# Twitter       43795
# Name: likes, dtype: int64

# %%
df.groupby("platform")[['likes','comments','shares']].sum()
# Out:
#             likes  comments  shares
# platform
# Facebook    86392      7965   15180
# Instagram  107994      8368   18906
# Twitter     43795      3933    7479

# %%
df.groupby("platform")[['likes','comments','shares']].mean()
# Out:
#                  likes    comments      shares
# platform
# Facebook   2699.750000  248.906250  474.375000
# Instagram  2999.833333  232.444444  525.166667
# Twitter    1368.593750  122.906250  233.718750

# %%
df.groupby("platform")['likes'].sum().apply(lambda x:"good" if x>50000 else "very good")
# Out:
# platform
# Facebook          good
# Instagram         good
# Twitter      very good
# Name: likes, dtype: object

# %%
df.groupby("platform",sort=True).head()
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 0         1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     694
# 2         3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3         4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5    Twitter     video    5/23/2023 0:30   3499       247     286
# 5         6  Instagram  carousel    5/5/2023 20:00    256       186     211
# 6         7  Instagram     image   2/26/2023 11:45   1982        30     906
# 7         8  Instagram      text  10/28/2023 19:30   1274        45     216
# 8         9   Facebook     video     5/2/2023 6:15    317       249     221
# 9        10    Twitter  carousel   5/11/2023 11:00   1878       225     438
# 10       11    Twitter      text    12/8/2023 2:15   1446        44      52
# ...

# %%
df.groupby("platform",sort=True).sample()
# Out:
#     post_id   platform post_type        post_time  likes  comments  shares  \
# 69       70   Facebook      text   6/12/2023 9:30   3094        86     965
# 86       87  Instagram      text  5/23/2023 22:30     15        70     454
# 50       51    Twitter      text  2/14/2023 18:00   1268        73     251
#
#    post_day sentiment_score
# 69   Monday        negative
# 86  Tuesday         neutral
# 50  Tuesday        positive

# %%
df.groupby("platform",sort=True).describe()
# Out:
#           post_id                                                       likes  \
#             count       mean        std  min    25%   50%    75%    max count
# platform
# Facebook     32.0  51.531250  29.195652  1.0  28.75  53.0  76.25   94.0  32.0
# Instagram    36.0  57.472222  28.866675  3.0  38.75  60.5  79.75  100.0  36.0
# Twitter      32.0  41.625000  27.492814  4.0  18.75  39.5  56.00   98.0  32.0
#
#                         ... comments        shares                          \
#                   mean  ...      75%    max  count        mean         std
# platform                ...
# Facebook   2699.750000  ...   393.00  500.0   32.0  474.375000  299.739430
# Instagram  2999.833333  ...   339.00  500.0   36.0  525.166667  284.467472
# Twitter    1368.593750  ...   162.25  247.0   32.0  233.718750  156.508525
#
#
#             min     25%    50%     75%    max
# platform
# Facebook   16.0  283.00  408.5  728.75  993.0
# Instagram  25.0  226.50  573.5  758.00  956.0
# ...

# %%
df.shape
# Out:
# (100, 9)

# %%
df.groupby('platform').size()
# Out:
# platform
# Facebook     32
# Instagram    36
# Twitter      32
# dtype: int64

# %%
df.groupby('platform').groups
# Out:
# {'Facebook': [0, 1, 8, 12, 14, 19, 25, 27, 28, 29, 30, 35, 36, 38, 46, 47, 57, 61, 65, 66, 69, 71, 72, 74, 79, 80, 83, 84, 87, 90, 91, 93], 'Instagram': [2, 5, 6, 7, 16, 23, 26, 31, 34, 39, 41, 43, 45, 49, 53, 55, 56, 59, 60, 63, 64, 67, 70, 73, 75, 77, 78, 81, 82, 86, 89, 92, 94, 95, 98, 99], 'Twitter': [3, 4, 9, 10, 11, 13, 15, 17, 18, 20, 21, 22, 24, 32, 33, 37, 40, 42, 44, 48, 50, 51, 52, 54, 58, 62, 68, 76, 85, 88, 96, 97]}

# %%
for i,j in df.groupby("platform"):
    print(i,"name")
    print(j,"data")
# Out:
# Facebook name
#     post_id  platform post_type         post_time  likes  comments  shares  \
# 0         1  Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2  Facebook  carousel    5/14/2023 0:45   3660       432     694
# 8         9  Facebook     video     5/2/2023 6:15    317       249     221
# 12       13  Facebook  carousel  11/11/2023 15:45     45        78     375
# 14       15  Facebook  carousel    1/9/2023 20:00    889       314     262
# 19       20  Facebook     image    2/2/2023 16:00    455        86      79
# 25       26  Facebook  carousel    10/5/2023 6:30   1992        70     515
# 27       28  Facebook      poll     3/1/2023 8:00   2083       500     388
# 28       29  Facebook     image    1/7/2023 10:30    548       153     731
# 29       30  Facebook  carousel     2/3/2023 0:30   4594       216     739
# 30       31  Facebook      poll   9/10/2023 13:45   4795       449     978
# ...

# %%
df.groupby('platform').nth(0)
# Out:
#            post_id post_type        post_time  likes  comments  shares  \
# platform
# Facebook         1     image  8/17/2023 14:45   2121       474     628
# Instagram        3      poll  2/21/2023 16:15   4955       408     688
# Twitter          4     image  11/16/2023 0:45   1183        90     187
#
#            post_day sentiment_score
# platform
# Facebook   Thursday        positive
# Instagram   Tuesday        negative
# Twitter    Thursday        negative

# %%
df.groupby('platform').nunique()
# Out:
#            post_id  post_type  post_time  likes  comments  shares  post_day  \
# platform
# Facebook        32          5         32     29        28      32         7
# Instagram       36          5         36     33        34      36         7
# Twitter         32          5         32     32        31      31         7
#
#            sentiment_score
# platform
# Facebook                 3
# Instagram                3
# Twitter                  3

# %%
df.groupby('platform').agg({"likes":sum,"comments":max})
# Out:
#             likes  comments
# platform
# Facebook    86392       500
# Instagram  107994       500
# Twitter     43795       247

# %%
df = pd.read_csv("ipl-matches.csv")

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df[((df['Team1']=='Mumbai Indians') | (df['Team2']=='Mumbai Indians')) & (df['WinningTeam']!='Mumbai Indians')]
# Out:
#           ID         City        Date   Season MatchNumber  \
# 9    1304111       Mumbai  2022-05-17     2022          65
# 18   1304102  Navi Mumbai  2022-05-09     2022          56
# 37   1304083       Mumbai  2022-04-24     2022          37
# 41   1304079  Navi Mumbai  2022-04-21     2022          33
# 48   1304072       Mumbai  2022-04-16     2022          26
# ..       ...          ...         ...      ...         ...
# 905   336028       Mumbai  2008-05-21  2007/08          45
# 937   335994       Mumbai  2008-04-27  2007/08          14
# 940   335991   Chandigarh  2008-04-25  2007/08          10
# 942   335989      Chennai  2008-04-23  2007/08           8
# 946   335985       Mumbai  2008-04-20  2007/08           5
#
#                      Team1                        Team2  \
# 9      Sunrisers Hyderabad               Mumbai Indians
# 18   Kolkata Knight Riders               Mumbai Indians
# 37    Lucknow Super Giants               Mumbai Indians
# ...

# %%
sum((df['WinningTeam']=='Mumbai Indians') & (df['City']=='Mumbai'))/(df['City']=='Mumbai').count()
# Out:
# 0.05894736842105263

# %%
sum(df.SuperOver=='Y')
# Out:
# 14

# %%
sum(df['TossWinner']==df['WinningTeam'])/df.TossWinner.count()
# Out:
# 0.5147368421052632

# %%
df[((df['Team1']=='Mumbai Indians') | (df['Team2']=='Mumbai Indians')) & (df['WinningTeam']!='Mumbai Indians')].Player_of_Match.value_counts()
# Out:
# KL Rahul         4
# SPD Smith        4
# SK Raina         4
# A Nehra          3
# V Sehwag         3
#                 ..
# KD Karthik       1
# PA Patel         1
# WP Saha          1
# BB McCullum      1
# Sohail Tanvir    1
# Name: Player_of_Match, Length: 68, dtype: int64
