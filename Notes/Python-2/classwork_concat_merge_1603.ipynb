# %%
import numpy as np
import pandas as pd

# %%
df1=pd.DataFrame({'A':[1,2],"B":[3,4]})
df2=pd.DataFrame({'A':[5,7],"B":[7,9]})
print(df1)
print(df2)
# Out:
#    A  B
# 0  1  3
# 1  2  4
#    A  B
# 0  5  7
# 1  7  9

# %%
pd.concat((df1,df2),axis=0)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  7  9

# %%
pd.concat((df1,df2),axis=1)
# Out:
#    A  B  A  B
# 0  1  3  5  7
# 1  2  4  7  9

# %%
df1=pd.DataFrame({'A':[1,2],"B":[3,4]})
df2=pd.DataFrame({'C':[5,7],"D":[7,9]})

# %%
pd.concat((df1,df2))
# Out:
#      A    B    C    D
# 0  1.0  3.0  NaN  NaN
# 1  2.0  4.0  NaN  NaN
# 0  NaN  NaN  5.0  7.0
# 1  NaN  NaN  7.0  9.0

# %%
df1=pd.DataFrame({'A':[1,2],"B":[3,4]})
df2=pd.DataFrame({'C':[5,7,10],"D":[7,9,11]})

# %%
pd.concat((df1,df2),axis=1)
# Out:
#      A    B   C   D
# 0  1.0  3.0   5   7
# 1  2.0  4.0   7   9
# 2  NaN  NaN  10  11

# %%
df1=pd.DataFrame({'A':[1,2],"B":[3,4]})
df2=pd.DataFrame({'A':[5,7],"B":[7,9]})

# %%
pd.concat((df1,df2),ignore_index=True)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 2  5  7
# 3  7  9

# %%
pd.concat((df1,df2),keys=['A1','B1'])
# Out:
#       A  B
# A1 0  1  3
#    1  2  4
# B1 0  5  7
#    1  7  9

# %%
df1=pd.DataFrame({'A':[1,2],"B":[3,4]})
df2=pd.DataFrame({'C':[5,7],"D":[7,9]})

# %%
pd.concat((df1,df2),ignore_index=True,axis=1)
# Out:
#    0  1  2  3
# 0  1  3  5  7
# 1  2  4  7  9

# %%
pd.concat((df1,df2),keys=['A1','B1'],axis=1)
# Out:
#   A1    B1
#    A  B  C  D
# 0  1  3  5  7
# 1  2  4  7  9

# %%
df1=pd.DataFrame({'A':[1,2],"B":[3,4]})
df2=pd.DataFrame({'C':[5,7],"B":[7,9]})

# %%
pd.concat((df1,df2),join="inner")
# Out:
#    B
# 0  3
# 1  4
# 0  7
# 1  9

# %%
df1=pd.DataFrame({'B':[1,2],"A":[3,4]})
df2=pd.DataFrame({'C':[5,7],"B":[7,9]})

# %%
pd.concat((df1,df2),join="outer",sort=True)
# Out:
#      A  B    C
# 0  3.0  1  NaN
# 1  4.0  2  NaN
# 0  NaN  7  5.0
# 1  NaN  9  7.0

# %%
df1=pd.DataFrame({"Sub":["FSD","Python","DM",],"Fac":["NAS","VYB","MSS"],"Id":[1,2,4]})
df2=pd.DataFrame({"Id":[1,2,3],"mark":[9,10,8]})

# %%
pd.merge(df1,df2,on="Id")
# Out:
#       Sub  Fac  Id  mark
# 0     FSD  NAS   1     9
# 1  Python  VYB   2    10

# %%
pd.merge(df1,df2,on="Id",how="outer")
# Out:
#       Sub  Fac  Id  mark
# 0     FSD  NAS   1   9.0
# 1  Python  VYB   2  10.0
# 2      DM  MSS   4   NaN
# 3     NaN  NaN   3   8.0

# %%
df1.merge(df2,on="Id")
# Out:
#       Sub  Fac  Id  mark
# 0     FSD  NAS   1     9
# 1  Python  VYB   2    10

# %%
pd.merge(df1,df2,on="Id",how="left")
# Out:
#       Sub  Fac  Id  mark
# 0     FSD  NAS   1   9.0
# 1  Python  VYB   2  10.0
# 2      DM  MSS   4   NaN

# %%
pd.merge(df1,df2,on="Id",how="right")
# Out:
#       Sub  Fac  Id  mark
# 0     FSD  NAS   1     9
# 1  Python  VYB   2    10
# 2     NaN  NaN   3     8

# %%
df1=pd.DataFrame({"Sub":["FSD","Python","DM",],"Fac":["NAS","VHA","MSS"],"Id_x":[1,2,4]})
df2=pd.DataFrame({"Id_y":[1,2,3],"mark":[9,10,8]})

# %%
df1.merge(df2,left_on="Id_x",right_on="Id_y")
# Out:
#       Sub  Fac  Id_x  Id_y  mark
# 0     FSD  NAS     1     1     9
# 1  Python  VHA     2     2    10

# %%
df1.merge(df2,left_index=True,right_index=True)
# Out:
#       Sub  Fac  Id_x  Id_y  mark
# 0     FSD  NAS     1     1     9
# 1  Python  VHA     2     2    10
# 2      DM  MSS     4     3     8

# %%
df1=pd.DataFrame({"Sub":["FSD","Python","DM",],"Fac":["NAS","VHA","MSS"],"Id_x":[1,2,4]})
df2=pd.DataFrame({"Id_y":[1,2,3],"mark":[9,10,8],"Fac":["NAS","VHA","MSS"]})

# %%
df1.merge(df2,left_on="Id_x",right_on="Id_y",suffixes=("_df1","_df2"))
# Out:
#       Sub Fac_df1  Id_x  Id_y  mark Fac_df2
# 0     FSD     NAS     1     1     9     NAS
# 1  Python     VHA     2     2    10     VHA

# %%
import seaborn as sns

# %%
df=pd.read_csv("auto-mpg.csv")

# %%
sns.boxplot(df.acceleration)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='acceleration'>

# %%
sns.boxplot(y="acceleration",hue="origin",data=df)
# Out:
# <AxesSubplot:ylabel='acceleration'>

# %% [markdown]
# ### `Q:1-5`
# 1. You are given three quater files, your job is to append these three files and make a single dataframe.
# 2. Have a index as Q-1 Q-2 Q-3 for respective quater files in the dataframe
# 3. Your are given a file items.csv which has item_id and item_name. Find out most sold items in each quarter.
# 4. Find out items which has made most revenue in each quarter.
# 5. Find out avg order price of each quarter.
#
# ***Note: item_price is given as str with $ sign, in earlier task you have converted this to rupees, here too first convert item_price field in rupees.***

# %%
# import like this
items_path = "items.csv"
q1_path = "quarter-1.csv"
q2_path = "quarter-2.csv"
q3_path = "quarter-3.csv"


q1= pd.read_csv(q1_path)
q2 = pd.read_csv(q2_path)
q3 = pd.read_csv(q3_path)

items = pd.read_csv(items_path)

# %%
print(q1)
print(q2)
print(q3)
# Out:
#       order_id  quantity  item_id  choice_description_id item_price
# 0            1         1        1                      1     $3.39
# 1            1         1        2                      2     $3.39
# 2            2         2        4                      3    $16.98
# 3            4         1        7                      6     $9.25
# 4            6         1        9                      8     $8.75
# ...        ...       ...      ...                    ...        ...
# 2270      1831         1       16                      0     $1.50
# 2271      1833         1        6                    276    $11.75
# 2272      1833         1        6                    904    $11.75
# 2273      1834         1       20                    303     $8.75
# 2274      1834         1       20                     30     $8.75
#
# [2275 rows x 5 columns]
#       order_id  quantity  item_id  choice_description_id item_price
# 0            1         1        0                      0     $2.39
# ...

# %%
df=pd.concat((q1,q2,q3),keys=["Q-1","Q-2","Q-3"])

# %%
df=df.reset_index()
df
# Out:
#      level_0  level_1 order_id quantity item_id choice_description_id  \
# 0        Q-1        0        1        1       1                     1
# 1        Q-1        1        1        1       2                     2
# 2        Q-1        2        2        2       4                     3
# 3        Q-1        3        4        1       7                     6
# 4        Q-1        4        6        1       9                     8
# ...      ...      ...      ...      ...     ...                   ...
# 4617     Q-2     2342     1829        1      23                    92
# 4618     Q-2     2343     1830        1      23                  1043
# 4619     Q-2     2344     1832        1      10                   116
# 4620     Q-2     2345     1832        1       8                     0
# 4621     Q-2     2346     1834        1      20                   515
#
#      item_price
# 0        $3.39
# 1        $3.39
# 2       $16.98
# 3        $9.25
# 4        $8.75
# ...         ...
# ...

# %%
df=pd.merge(df,items,on="item_id")
df
# Out:
#      level_0  level_1 order_id quantity item_id choice_description_id  \
# 0        Q-1        0        1        1       1                     1
# 1        Q-1       10       12        1       1                    18
# 2        Q-1       25       21        1       1                    33
# 3        Q-1       34       30        1       1                    33
# 4        Q-1      179      155        1       1                    33
# ...      ...      ...      ...      ...     ...                   ...
# 4617     Q-2     1411     1094        1      48                   755
# 4618     Q-2     1528     1192        1      48                   149
# 4619     Q-2     1605     1263        1      48                   306
# 4620     Q-2     1745     1395        1      48                   755
# 4621     Q-2      826      668        1      47                   217
#
#      item_price            item_name
# 0        $3.39                  Izze
# 1        $3.39                  Izze
# ...

# %%
df.groupby(["level_0","item_name"],as_index=False)["quantity"].sum().sort_values("quantity",ascending=False).drop_duplicates(subset=["level_0"])
# Out:
#    level_0     item_name  quantity
# 65     Q-2  Chicken Bowl       394
# 17     Q-1  Chicken Bowl       367

# %%
df["item_price"]=df["item_price"].apply(lambda x:float(x[1:]))

# %%
df
# Out:
#      level_0  level_1 order_id quantity item_id choice_description_id  \
# 0        Q-1        0        1        1       1                     1
# 1        Q-1       10       12        1       1                    18
# 2        Q-1       25       21        1       1                    33
# 3        Q-1       34       30        1       1                    33
# 4        Q-1      179      155        1       1                    33
# ...      ...      ...      ...      ...     ...                   ...
# 4617     Q-2     1411     1094        1      48                   755
# 4618     Q-2     1528     1192        1      48                   149
# 4619     Q-2     1605     1263        1      48                   306
# 4620     Q-2     1745     1395        1      48                   755
# 4621     Q-2      826      668        1      47                   217
#
#       item_price            item_name
# 0           3.39                 Izze
# 1           3.39                 Izze
# ...

# %%
df["total_price"]=df["item_price"]*df["quantity"]
df
# Out:
#      level_0  level_1 order_id quantity item_id choice_description_id  \
# 0        Q-1        0        1        1       1                     1
# 1        Q-1       10       12        1       1                    18
# 2        Q-1       25       21        1       1                    33
# 3        Q-1       34       30        1       1                    33
# 4        Q-1      179      155        1       1                    33
# ...      ...      ...      ...      ...     ...                   ...
# 4617     Q-2     1411     1094        1      48                   755
# 4618     Q-2     1528     1192        1      48                   149
# 4619     Q-2     1605     1263        1      48                   306
# 4620     Q-2     1745     1395        1      48                   755
# 4621     Q-2      826      668        1      47                   217
#
#       item_price            item_name total_price
# 0           3.39                 Izze        3.39
# ...

# %%
df.groupby(["level_0","item_name"],as_index=False)["total_price"].sum().sort_values("total_price",ascending=False).drop_duplicates([])
# Out:
#    level_0     item_name  total_price
# 65     Q-2  Chicken Bowl      4192.25
# 17     Q-1  Chicken Bowl      3852.38

# %%
x=df.groupby(["level_0","order_id"],as_index=False)["total_price"].sum()
x
# Out:
#      level_0  order_id  total_price
# 0        Q-1         1         6.78
# 1        Q-1         2        33.96
# 2        Q-1         4         9.25
# 3        Q-1         6        17.50
# 4        Q-1         7        11.25
# ...      ...       ...          ...
# 2892     Q-2      1828         4.45
# 2893     Q-2      1829        11.25
# 2894     Q-2      1830        11.25
# 2895     Q-2      1832        13.20
# 2896     Q-2      1834        11.25
#
# [2897 rows x 3 columns]

# %%
x.groupby("level_0")["total_price"].mean()
# Out:
# level_0
# Q-1    13.809488
# Q-2    13.279828
# Name: total_price, dtype: float64
