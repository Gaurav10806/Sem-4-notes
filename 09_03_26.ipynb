# %%
import pandas as pd
import numpy as np

# %%
ds = pd.Series([10,20,30,40], index=['a','b','c','d'], dtype='float', name='GHS')
print(ds)
# Out:
# a    10.0
# b    20.0
# c    30.0
# d    40.0
# Name: GHS, dtype: float64

# %%
ds = pd.Series([10,20,30,40], index=('v','h','a','b'), dtype='float', name='GHS')
print(ds)
# Out:
# v    10.0
# h    20.0
# a    30.0
# b    40.0
# Name: GHS, dtype: float64

# %%
ds = pd.Series({10:20,30:40}, dtype='float', name='GHS')
print(ds)
# Out:
# 10    20.0
# 30    40.0
# Name: GHS, dtype: float64

# %%
ds = pd.Series(np.array([10,20,30,40]), index=['v','h','a','b'], dtype='float', name='GHS')
print(ds)
# Out:
# v    10.0
# h    20.0
# a    30.0
# b    40.0
# Name: GHS, dtype: float64

# %%
ds = pd.DataFrame([['A','B','C'],[10,20,30],[1,2,3]], index=['p','q','r'], columns=['a','b','c'])
print(ds)
# Out:
#     a   b     c
# p   A   B   NaN
# q  10  20  30.0
# r   1   2   3.0

# %%
ds = pd.DataFrame((('A','B','C'),(10,20,30),(1,None,3)), index=['p','q','r'], columns=['a','b','c'])
print(ds)
# Out:
#     a     b   c
# p   A     B   C
# q  10    20  30
# r   1  None   3

# %%
ds = pd.DataFrame({'name': ['a','b','c'],'mark':[10,20,30], 'cgpa':[10,9.8,9.7]},index=['a','b','c'])
print(ds)
# Out:
#   name  mark  cgpa
# a    a    10  10.0
# b    b    20   9.8
# c    c    30   9.7

# %%
ds = pd.DataFrame([{'name':'Gaurav', 'mark':10},{'name':'GHS', 'mark':10}])
print(ds)
# Out:
#      name  mark
# 0  Gaurav    10
# 1     GHS    10

# %%
df = pd.read_csv('train.csv')
df.index
df.columns
df.size
df.shape
df.values
df.dtypes
df.ndim
df.T
df = df.set_index('Name')
df = df.reset_index()
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
df1 = pd.DataFrame({'name':['A','B','C'],'mark':[10,20,30],'CGPI':[7,8,9]},index=['G','H','S'],columns=['name','mark','CGPI'])
df1
# Out:
#   name  mark  CGPI
# G    A    10     7
# H    B    20     8
# S    C    30     9

# %%
df1.set_index('name',drop=True)
# Out:
#       mark  CGPI
# name
# A       10     7
# B       20     8
# C       30     9

# %%
df1.reset_index()
df1
# Out:
#   name  mark  CGPI
# G    A    10     7
# H    B    20     8
# S    C    30     9

# %%
df = pd.read_csv('train.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df['Name'])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Name','Pclass']]
# type(df[['Name','Pclass']])
# Out:
#                                                   Name  Pclass
# 0                              Braund, Mr. Owen Harris       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                               Heikkinen, Miss. Laina       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4                             Allen, Mr. William Henry       3
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas       2
# 887                       Graham, Miss. Margaret Edith       1
# 888           Johnston, Miss. Catherine Helen "Carrie"       3
# 889                              Behr, Mr. Karl Howell       1
# 890                                Dooley, Mr. Patrick       3
#
# [891 rows x 2 columns]

# %%
df.iloc[2,3]
df.iloc[2]
df.iloc[2:3,:]
# Out:
#    PassengerId  Survived  Pclass                    Name     Sex   Age  SibSp  \
# 2            3         1       3  Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 2      0  STON/O2. 3101282  7.925   NaN        S

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[1:0]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df = df.set_index('Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-eee61f0e40b0> in <module>
# ----> 1 df = df.set_index('Name')
#       2 df.loc['Braund, Mr. Owen Harris']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['Name'] are in the columns"

# %%
df = df.set_index('Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-3d2ab96ddafa> in <module>
# ----> 1 df = df.set_index('Name')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['Name'] are in the columns"

# %%
df.loc['Braund, Mr. Owen Harris']
# Out:
# PassengerId       1
# Survived          0
# Pclass            3
# Sex            male
# Age              22
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
df.loc['Braund, Mr. Owen Harris','PassengerId':'Age']
# Out:
# PassengerId       1
# Survived          0
# Pclass            3
# Sex            male
# Age              22
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
df2 = pd.DataFrame({'P':[10,20,30],'Q':[40,50,60],'R':[70,80,90]},index=['A','B','C'])
print(df2)
# Out:
#     P   Q   R
# A  10  40  70
# B  20  50  80
# C  30  60  90

# %%
df2.loc['B','Q']
# Out:
# 50

# %%
df2.loc[:,'R']
# Out:
# A    70
# B    80
# C    90
# Name: R, dtype: int64

# %%
df2.loc['B','Q']=100
df2
# Out:
#     P    Q   R
# A  10   40  70
# B  20  100  80
# C  30   60  90

# %%
df2['D']=[7,8,9]
df2['E']=8
df2
# Out:
#     P    Q   R  D  E
# A  10   40  70  7  8
# B  20  100  80  8  8
# C  30   60  90  9  8

# %%
df2['D'] = df2['P'] * df2['Q']
df2
# Out:
#     P    Q   R     D  E
# A  10   40  70   400  8
# B  20  100  80  2000  8
# C  30   60  90  1800  8

# %%
df2.loc['A':'C','P':'R'] = 7
df2
# Out:
#    P  Q  R     D  E
# A  7  7  7   400  8
# B  7  7  7  2000  8
# C  7  7  7  1800  8
